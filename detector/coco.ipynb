# %%
#@markdown We implemented some functions to visualize the object detection results. <br/> Run the following cell to activate the functions.
import cv2
import numpy as np
import os
MARGIN = 10  # pixels
ROW_SIZE = 10  # pixels
FONT_SIZE = 1
FONT_THICKNESS = 1
TEXT_COLOR = (255, 0, 0)  # red


def visualize(
    image,
    detection_result
) -> np.ndarray:
  """Draws bounding boxes on the input image and return it.
  Args:
    image: The input RGB image.
    detection_result: The list of all "Detection" entities to be visualize.
  Returns:
    Image with bounding boxes.
  """
  for detection in detection_result.detections:
    # Draw bounding_box
    bbox = detection.bounding_box
    start_point = bbox.origin_x, bbox.origin_y
    end_point = bbox.origin_x + bbox.width, bbox.origin_y + bbox.height
    cv2.rectangle(image, start_point, end_point, TEXT_COLOR, 3)

    # Draw label and score
    category = detection.categories[0]
    category_name = category.category_name
    probability = round(category.score, 2)
    result_text = category_name + ' (' + str(probability) + ')'
    text_location = (MARGIN + bbox.origin_x,
                     MARGIN + ROW_SIZE + bbox.origin_y)
    cv2.putText(image, result_text, text_location, cv2.FONT_HERSHEY_PLAIN,
                FONT_SIZE, TEXT_COLOR, FONT_THICKNESS)

  return image

# %%
# STEP 1: Import the necessary modules.
import numpy as np
import os
import mediapipe as mp
import time
import cv2
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import customtkinter
from tkinter import Tk
from tkinter import *
from tkinter import ttk
from tkinter import filedialog
from tkinter.filedialog import askdirectory

# STEP 2: Create an ObjectDetector object.
base_options = python.BaseOptions(model_asset_path="efficientdet_lite0.tflite")
options = vision.ObjectDetectorOptions(base_options=base_options, score_threshold=0.4)
detector = vision.ObjectDetector.create_from_options(options)


# input variable for implementation
con = []
out = []

customtkinter.set_appearance_mode("dark")
customtkinter.set_default_color_theme("dark-blue")

root = customtkinter.CTk()
root.geometry("500x350")
root.title('CocoAI')
root.iconbitmap("AppLogo.ico")

tabview = customtkinter.CTkTabview(master=root)
tabview.pack(pady=20, padx=60, fill="both", expand=True)

tabview.add("Scan")
tabview.add("Search")
tabview.set("Scan")

def path_entry():
    global dir
    global con 
    con = []
    dir = askdirectory(title='Select Folder')
    # start; goes to path
    for x in os.listdir(dir):
        # searches for specific filetypes
        if x.endswith(".jpg"):
            con.append(x)   
    # eliminates empty strings from list
    con = list(filter(None, con))
    print(con)
    text.configure(text=con)


def image_scan():
    fscan = 0
    while fscan < (len(con)):
        # STEP 3: Load the input image.
        image = mp.Image.create_from_file(dir + "/" +  con[fscan])
        # STEP 4: Detect objects in the input image.
        detection_result = detector.detect(image)
        result = str(detection_result)

        # result decode
        res = result.split() #split result in words; first pruning
        cls = [] #output list
        nres = len(res) #number of words 
        i = 1
        while i < nres:
            # searches words in res with "category_name" to find class args
            if "category_name" in res[i]:
                j = 14
                obj = str()
                # value of args found after "category_name="; prunes over each letter stopping before ")"
                while res[i][j] != ")":
                    obj += res[i][j]
                    j += 1
                # output has double brackets "" and '' due to input style
                cls.append(obj)
            i += 1
        # final pruning; eliminates double brackets
        cls = [sub.replace("'", "") for sub in cls]
        cls = list(dict.fromkeys(cls))
        print(cls)
        out.append(dir + "/" + con[fscan])
        out.append(cls)

        # STEP 5: Process the detection result. In this case, visualize it.
        image_copy = np.copy(image.numpy_view())
        annotated_image = visualize(image_copy, detection_result)
        rgb_annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)
        cv2.imread(con[fscan])
        cv2.imshow("coco", rgb_annotated_image)
        cv2.waitKey(0)
        fscan += 1   
    print(out)
    text2.configure(text=out)


def search():
    command = entry2.get()
    # search algorythm
    f = 1
    nr_res = 0
    while f < len(out):
        if command in out[f]:
            nr_res += 1
            print("Found in image: ", out[f-1])
            text3.configure(text="Found in image: " + out[f-1])
        f += 2
    if nr_res == 0:
        print("No results found")
        text3.configure(text="No results found")

label =customtkinter.CTkLabel(tabview.tab("Scan"), text="Insert Folder path")
label.pack(pady=12, padx=10)

# path to folder box
entry1 = customtkinter.CTkButton(tabview.tab("Scan"), text="Select", command= path_entry )
entry1.pack()

# output folder scan
text = customtkinter.CTkLabel(tabview.tab("Scan"), width=40, height=10, text="")
text.pack()

# confirm scan
button1 = customtkinter.CTkButton(tabview.tab("Scan"), text="Scan", command= image_scan )
button1.pack()

# image scan output
text2 = customtkinter.CTkLabel(tabview.tab("Scan"), width=40, height=10, text="")
text2.pack()

# search intruction
label =customtkinter.CTkLabel(tabview.tab("Search"), text="Search elements in images")
label.pack(pady=12, padx=10)

# search box
entry2 = customtkinter.CTkEntry(tabview.tab("Search"), placeholder_text="Search elements in images: ")
entry2.pack(pady=12, padx=10)

# confirm search
button2 = customtkinter.CTkButton(tabview.tab("Search"), text="Search", command= search)
button2.pack()

# search output
text3 = customtkinter.CTkLabel(tabview.tab("Search"), width=40, height=10, text="")
text3.pack()

root.mainloop()
# Out:
# ['information for young people banner - Copia (10).jpg', 'information for young people banner - Copia (11).jpg', 'information for young people banner - Copia (12).jpg', 'information for young people banner - Copia (13).jpg', 'information for young people banner - Copia (14).jpg', 'information for young people banner - Copia (15).jpg', 'information for young people banner - Copia (16).jpg', 'information for young people banner - Copia (17).jpg', 'information for young people banner - Copia (18).jpg', 'information for young people banner - Copia (19).jpg', 'information for young people banner - Copia (2).jpg', 'information for young people banner - Copia (3).jpg', 'information for young people banner - Copia (4).jpg', 'information for young people banner - Copia (5).jpg', 'information for young people banner - Copia (6).jpg', 'information for young people banner - Copia (7).jpg', 'information for young people banner - Copia (8).jpg', 'information for young people banner - Copia (9).jpg', 'information for young people banner - Copia.jpg', 'information for young people banner.jpg', 'pexels-andrea-piacquadio-837358 - Copia (10).jpg', 'pexels-andrea-piacquadio-837358 - Copia (11).jpg', 'pexels-andrea-piacquadio-837358 - Copia (12).jpg', 'pexels-andrea-piacquadio-837358 - Copia (13).jpg', 'pexels-andrea-piacquadio-837358 - Copia (14).jpg', 'pexels-andrea-piacquadio-837358 - Copia (15).jpg', 'pexels-andrea-piacquadio-837358 - Copia (16).jpg', 'pexels-andrea-piacquadio-837358 - Copia (17).jpg', 'pexels-andrea-piacquadio-837358 - Copia (18).jpg', 'pexels-andrea-piacquadio-837358 - Copia (19).jpg', 'pexels-andrea-piacquadio-837358 - Copia (2).jpg', 'pexels-andrea-piacquadio-837358 - Copia (3).jpg', 'pexels-andrea-piacquadio-837358 - Copia (4).jpg', 'pexels-andrea-piacquadio-837358 - Copia (5).jpg', 'pexels-andrea-piacquadio-837358 - Copia (6).jpg', 'pexels-andrea-piacquadio-837358 - Copia (7).jpg', 'pexels-andrea-piacquadio-837358 - Copia (8).jpg', 'pexels-andrea-piacquadio-837358 - Copia (9).jpg', 'pexels-andrea-piacquadio-837358 - Copia.jpg', 'pexels-andrea-piacquadio-837358.jpg', 'wcms_855046 - Copia (10).jpg', 'wcms_855046 - Copia (11).jpg', 'wcms_855046 - Copia (12).jpg', 'wcms_855046 - Copia (13).jpg', 'wcms_855046 - Copia (14).jpg', 'wcms_855046 - Copia (15).jpg', 'wcms_855046 - Copia (16).jpg', 'wcms_855046 - Copia (17).jpg', 'wcms_855046 - Copia (18).jpg', 'wcms_855046 - Copia (19).jpg', 'wcms_855046 - Copia (2).jpg', 'wcms_855046 - Copia (3).jpg', 'wcms_855046 - Copia (4).jpg', 'wcms_855046 - Copia (5).jpg', 'wcms_855046 - Copia (6).jpg', 'wcms_855046 - Copia (7).jpg', 'wcms_855046 - Copia (8).jpg', 'wcms_855046 - Copia (9).jpg', 'wcms_855046 - Copia.jpg', 'wcms_855046.jpg']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['person']
# ['D:/Python/Coco/detector/large photo test/information for young people banner - Copia (10).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (11).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (12).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (13).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (14).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (15).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (16).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (17).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (18).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (19).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (2).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (3).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (4).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (5).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (6).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (7).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (8).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia (9).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner - Copia.jpg', ['person'], 'D:/Python/Coco/detector/large photo test/information for young people banner.jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (10).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (11).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (12).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (13).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (14).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (15).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (16).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (17).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (18).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (19).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (2).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (3).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (4).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (5).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (6).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (7).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio-837358 - Copia (8).jpg', ['person'], 'D:/Python/Coco/detector/large photo test/pexels-andrea-piacquadio- ...

# %%
# STEP 1: Import the necessary modules.
import numpy as np
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# STEP 2: Create an ObjectDetector object.
base_options = python.BaseOptions(model_asset_path='efficientdet.tflite')
options = vision.ObjectDetectorOptions(base_options=base_options,
                                       score_threshold=0.5)
detector = vision.ObjectDetector.create_from_options(options)

# STEP 3: Load the input image.
image = mp.Image.create_from_file("D:\Python\Coco\detector\large photo test")

# STEP 4: Detect objects in the input image.
detection_result = detector.detect(image)

# STEP 5: Process the detection result. In this case, visualize it.
image_copy = np.copy(image.numpy_view())
annotated_image = visualize(image_copy, detection_result)
rgb_annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)
cv2_imshow(rgb_annotated_image)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 11
#       8 base_options = python.BaseOptions(model_asset_path='efficientdet.tflite')
#       9 options = vision.ObjectDetectorOptions(base_options=base_options,
#      10                                        score_threshold=0.5)
# ---> 11 detector = vision.ObjectDetector.create_from_options(options)
#      13 # STEP 3: Load the input image.
#      14 image = mp.Image.create_from_file("D:\Python\Coco\detector\large photo test")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mediapipe\tasks\python\vision\object_detector.py:234, in ObjectDetector.create_from_options(cls, options)
#     220   options.result_callback(detection_result, image, timestamp)
#     222 task_info = _TaskInfo(
#     223     task_graph=_TASK_GRAPH_NAME,
#     224     input_streams=[
#    (...)
#     232     task_options=options,
#     233 )
# --> 234 return cls(
#     235     task_info.generate_graph_config(
#     236         enable_flow_limiting=options.running_mode
#     237         == _RunningMode.LIVE_STREAM
#     238     ),
#     239     options.running_mode,
#     240     packets_callback if options.result_callback else None,
#     241 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mediapipe\tasks\python\vision\core\base_vision_task_api.py:70, in BaseVisionTaskApi.__init__(self, graph_config, running_mode, packet_callback)
#      65 elif packet_callback:
#      66   raise ValueError(
#      67       'The vision task is in image or video mode, a user-defined result '
#      68       'callback should not be provided.'
#      69   )
# ---> 70 self._runner = _TaskRunner.create(graph_config, packet_callback)
#      71 self._running_mode = running_mode
#
# RuntimeError: Unable to open file at D:\Python\Coco\detector\efficientdet.tflite
